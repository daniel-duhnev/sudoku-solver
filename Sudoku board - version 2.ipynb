# %% [markdown]
# ### Version 2: With squares
#
# Can solve harder sudokus

# %%
import numpy as np

# %%
def add_possibility(board, i, j, k):
    if board[j][k] == 0:
        if board[j][k] != i:
            board[j][k] = []
            board[j][k].append(i)
    elif isinstance(board[j][k],list) and i not in board[j][k]:
        board[j][k].append(i)


def add_all_possibilities(board):
    for i in range(1,10):
        for j in range(9):
            for k in range(9):
                    if i not in board[j] and i not in np.array(board, dtype=object)[:,k]:
                        if j <= 2:
                            if k <= 2:
                                if i not in np.array(board,dtype=object)[0:3, 0:3]:
                                    add_possibility(board,i,j,k)
                            elif k <=5 and k > 2:
                                if i not in np.array(board,dtype=object)[0:3, 3:6]:
                                    add_possibility(board,i,j,k)
                            elif k <=8 and k > 5:
                                if i not in np.array(board,dtype=object)[0:3, 6:9]:
                                    add_possibility(board,i,j,k)
                        elif j <=5 and j > 2:
                            if k <=2:
                                if i not in np.array(board,dtype=object)[3:6, 0:3]:
                                    add_possibility(board,i,j,k)
                            elif k <=5 and k > 2:
                                if i not in np.array(board,dtype=object)[3:6, 3:6]:
                                    add_possibility(board,i,j,k)
                            elif k <=8 and k > 5:
                                if i not in np.array(board,dtype=object)[3:6, 6:9]:
                                    add_possibility(board,i,j,k)
                        elif j <=8 and j > 5:
                            if k <=2:
                                if i not in np.array(board,dtype=object)[6:9, 0:3]:
                                    add_possibility(board,i,j,k)
                            elif k <=5 and k > 2:
                                if i not in np.array(board,dtype=object)[6:9, 3:6]:
                                    add_possibility(board,i,j,k)
                            elif k <=8 and k > 5:
                                if i not in np.array(board,dtype=object)[6:9, 6:9]:
                                    add_possibility(board,i,j,k)

def fill_box(board):
    for i in range(1,10):
        for j in range(9):
            for k in range(9):
                if isinstance(board[j][k], list) and len(board[j][k]) == 1:
                    board[j][k] = board[j][k][0]

def remove_possibility(board, i, j, k):
    if isinstance(board[j][k],list) and i in board[j][k]:
        board[j][k].remove(i)

def remove_row_column_possibilities(board):
    for i in range(1,10):
        for j in range(9):
            for k in range(9):
                if i in board[j] or i in np.array(board, dtype=object)[:,k]:
                    remove_possibility(board,i,j,k)

def remove_square_possibilities(board):
    for i in range(1,10):
            for j in range(9):
                for k in range(9):
                    if j <= 2:
                        if k <= 2:
                            if i in np.array(board,dtype=object)[0:3, 0:3]:
                                remove_possibility(board,i,j,k)
                        elif k <=5 and k > 2:
                            if i in np.array(board,dtype=object)[0:3, 3:6]:
                                remove_possibility(board,i,j,k)
                        elif k <=8 and k > 5:
                            if i in np.array(board,dtype=object)[0:3, 6:9]:
                                remove_possibility(board,i,j,k)
                    elif j <=5 and j > 2:
                        if k <=2:
                            if i in np.array(board,dtype=object)[3:6, 0:3]:
                                remove_possibility(board,i,j,k)
                        elif k <=5 and k > 2:
                            if i in np.array(board,dtype=object)[3:6, 3:6]:
                                remove_possibility(board,i,j,k)
                        elif k <=8 and k > 5:
                            if i in np.array(board,dtype=object)[3:6, 6:9]:
                                remove_possibility(board,i,j,k)
                    elif j <=8 and j > 5:
                        if k <=2:
                            if i in np.array(board,dtype=object)[6:9, 0:3]:
                                remove_possibility(board,i,j,k)
                        elif k <=5 and k > 2:
                            if i in np.array(board,dtype=object)[6:9, 3:6]:
                                remove_possibility(board,i,j,k)
                        elif k <=8 and k > 5:
                            if i in np.array(board,dtype=object)[6:9, 6:9]:
                                remove_possibility(board,i,j,k)

# %%
def sudoku_solver(board):
    add_all_possibilities(board)
    print(np.array(board, dtype=object))
    
    fill_box(board)
    print("\n"*2,np.array(board, dtype=object))

    remove_row_column_possibilities(board)
    print("\n"*2,np.array(board, dtype=object))
    
    remove_square_possibilities(board)
    print("\n"*2,np.array(board, dtype=object))
    
    x = []

    for i in np.array(board, dtype=object):
        for j in range(9):
            x.append(isinstance(i[j], list))
    if any(i for i in x) is True:
        print("\nBOARD!:",board,"\n")
        print("\nSTART OVER\n")
        sudoku_solver(board)
    else:
        print("\nFINISH!!\n",np.array(board, dtype=object))

# %%
board_array = [ [5,0,0, 4,6,7, 3,0,9],
                [9,0,3, 8,1,0, 4,2,7],
                [1,7,4, 2,0,3, 0,0,0],

                [2,3,1, 9,7,6, 8,5,4],
                [8,5,7, 1,2,4, 0,9,0],
                [4,9,6, 3,0,8, 1,7,2],

                [0,0,0, 0,8,9, 2,6,0],
                [7,8,2, 6,4,1, 0,0,5],
                [0,1,0, 0,0,0, 7,0,8]
                ]

sudoku_solver(board_array)
# Out:
# [[5 list([2]) list([8]) 4 6 7 3 list([1, 8]) 9]
#  [9 list([6]) 3 8 1 list([5]) 4 2 7]
#  [1 7 4 2 list([5, 9]) 3 list([5, 6]) list([8]) list([6])]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 list([6]) 9 list([3, 6])]
#  [4 9 6 3 list([5]) 8 1 7 2]
#  [list([3]) list([4]) list([5]) list([5, 7]) 8 9 2 6 list([1, 3])]
#  [7 8 2 6 4 1 list([9]) list([3]) 5]
#  [list([3, 6]) 1 list([5, 9]) list([5]) list([3, 5]) list([2, 5]) 7
#   list([3, 4]) 8]]
#
#
#  [[5 2 8 4 6 7 3 list([1, 8]) 9]
#  [9 6 3 8 1 5 4 2 7]
#  [1 7 4 2 list([5, 9]) 3 list([5, 6]) 8 6]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 6 9 list([3, 6])]
#  [4 9 6 3 5 8 1 7 2]
#  [3 4 5 list([5, 7]) 8 9 2 6 list([1, 3])]
#  [7 8 2 6 4 1 9 3 5]
#  [list([3, 6]) 1 list([5, 9]) 5 list([3, 5]) list([2, 5]) 7 list([3, 4])
#   8]]
#
#
#  [[5 2 8 4 6 7 3 list([1]) 9]
#  [9 6 3 8 1 5 4 2 7]
#  [1 7 4 2 list([9]) 3 list([5]) 8 6]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 6 9 list([3])]
#  [4 9 6 3 5 8 1 7 2]
#  [3 4 5 list([7]) 8 9 2 6 list([1])]
#  [7 8 2 6 4 1 9 3 5]
#  [list([6]) 1 list([9]) 5 list([3]) list([2]) 7 list([4]) 8]]
#
#
#  [[5 2 8 4 6 7 3 list([1]) 9]
#  [9 6 3 8 1 5 4 2 7]
#  [1 7 4 2 list([9]) 3 list([5]) 8 6]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 6 9 list([3])]
#  [4 9 6 3 5 8 1 7 2]
#  [3 4 5 list([7]) 8 9 2 6 list([1])]
#  [7 8 2 6 4 1 9 3 5]
#  [list([6]) 1 list([9]) 5 list([3]) list([2]) 7 list([4]) 8]]
# [[5, 2, 8, 4, 6, 7, 3, [1], 9], [9, 6, 3, 8, 1, 5, 4, 2, 7], [1, 7, 4, 2, [9], 3, [5], 8, 6], [2, 3, 1, 9, 7, 6, 8, 5, 4], [8, 5, 7, 1, 2, 4, 6, 9, [3]], [4, 9, 6, 3, 5, 8, 1, 7, 2], [3, 4, 5, [7], 8, 9, 2, 6, [1]], [7, 8, 2, 6, 4, 1, 9, 3, 5], [[6], 1, [9], 5, [3], [2], 7, [4], 8]]
#
# START OVER
#
# [[5 2 8 4 6 7 3 list([1]) 9]
#  [9 6 3 8 1 5 4 2 7]
#  [1 7 4 2 list([9]) 3 list([5]) 8 6]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 6 9 list([3])]
#  [4 9 6 3 5 8 1 7 2]
#  [3 4 5 list([7]) 8 9 2 6 list([1])]
#  [7 8 2 6 4 1 9 3 5]
#  [list([6]) 1 list([9]) 5 list([3]) list([2]) 7 list([4]) 8]]
#
#
#  [[5 2 8 4 6 7 3 1 9]
#  [9 6 3 8 1 5 4 2 7]
#  [1 7 4 2 9 3 5 8 6]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 6 9 3]
#  [4 9 6 3 5 8 1 7 2]
#  [3 4 5 7 8 9 2 6 1]
#  [7 8 2 6 4 1 9 3 5]
#  [6 1 9 5 3 2 7 4 8]]
#
#
#  [[5 2 8 4 6 7 3 1 9]
#  [9 6 3 8 1 5 4 2 7]
#  [1 7 4 2 9 3 5 8 6]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 6 9 3]
#  [4 9 6 3 5 8 1 7 2]
#  [3 4 5 7 8 9 2 6 1]
#  [7 8 2 6 4 1 9 3 5]
#  [6 1 9 5 3 2 7 4 8]]
#
#
#  [[5 2 8 4 6 7 3 1 9]
#  [9 6 3 8 1 5 4 2 7]
#  [1 7 4 2 9 3 5 8 6]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 6 9 3]
#  [4 9 6 3 5 8 1 7 2]
#  [3 4 5 7 8 9 2 6 1]
#  [7 8 2 6 4 1 9 3 5]
#  [6 1 9 5 3 2 7 4 8]]
# [[5, 2, 8, 4, 6, 7, 3, 1, 9], [9, 6, 3, 8, 1, 5, 4, 2, 7], [1, 7, 4, 2, 9, 3, 5, 8, 6], [2, 3, 1, 9, 7, 6, 8, 5, 4], [8, 5, 7, 1, 2, 4, 6, 9, 3], [4, 9, 6, 3, 5, 8, 1, 7, 2], [3, 4, 5, 7, 8, 9, 2, 6, 1], [7, 8, 2, 6, 4, 1, 9, 3, 5], [6, 1, 9, 5, 3, 2, 7, 4, 8]]
#
# FINISH!!
#  [[5 2 8 4 6 7 3 1 9]
#  [9 6 3 8 1 5 4 2 7]
#  [1 7 4 2 9 3 5 8 6]
#  [2 3 1 9 7 6 8 5 4]
#  [8 5 7 1 2 4 6 9 3]
#  [4 9 6 3 5 8 1 7 2]
#  [3 4 5 7 8 9 2 6 1]
#  [7 8 2 6 4 1 9 3 5]
#  [6 1 9 5 3 2 7 4 8]]

# %%
board_array = [ [0,5,0, 0,0,3, 7,0,0],
                [8,3,1, 4,2,7, 0,0,5],
                [9,7,4, 0,8,6, 1,2,3],
               
                [3,8,6, 1,4,0, 2,5,7],
                [7,0,5, 0,0,0, 0,0,0],
                [0,4,9, 7,0,2, 8,3,6],
               
                [5,0,0, 0,7,4, 0,9,8],
                [0,9,0, 3,0,1, 0,0,2],
                [2,0,0, 0,9,0, 3,0,1]
                ]

sudoku_solver(board_array)
# Out:
# [[list([6]) 5 list([2]) list([9]) list([1]) 3 7 list([4, 6, 8])
#   list([4, 9])]
#  [8 3 1 4 2 7 list([6, 9]) list([6]) 5]
#  [9 7 4 list([5]) 8 6 1 2 3]
#  [3 8 6 1 4 list([9]) 2 5 7]
#  [7 list([1, 2]) 5 list([6, 8, 9]) list([3, 6]) list([8, 9]) list([4, 9])
#   list([1, 4]) list([4, 9])]
#  [list([1]) 4 9 7 list([5]) 2 8 3 6]
#  [5 list([1, 6]) list([3]) list([2, 6]) 7 4 list([6]) 9 8]
#  [list([4, 6]) 9 list([7, 8]) 3 list([5, 6]) 1 list([4, 5, 6])
#   list([4, 6, 7]) 2]
#  [2 list([6]) list([7, 8]) list([5, 6, 8]) 9 list([5, 8]) 3
#   list([4, 6, 7]) 1]]
#
#
#  [[6 5 2 9 1 3 7 list([4, 6, 8]) list([4, 9])]
#  [8 3 1 4 2 7 list([6, 9]) 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 list([1, 2]) 5 list([6, 8, 9]) list([3, 6]) list([8, 9]) list([4, 9])
#   list([1, 4]) list([4, 9])]
#  [1 4 9 7 5 2 8 3 6]
#  [5 list([1, 6]) 3 list([2, 6]) 7 4 6 9 8]
#  [list([4, 6]) 9 list([7, 8]) 3 list([5, 6]) 1 list([4, 5, 6])
#   list([4, 6, 7]) 2]
#  [2 6 list([7, 8]) list([5, 6, 8]) 9 list([5, 8]) 3 list([4, 6, 7]) 1]]
#
#
#  [[6 5 2 9 1 3 7 list([4, 8]) list([4])]
#  [8 3 1 4 2 7 list([9]) 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 list([1, 2]) 5 list([6, 8]) list([3, 6]) list([8]) list([4, 9])
#   list([1, 4]) list([4, 9])]
#  [1 4 9 7 5 2 8 3 6]
#  [5 list([1]) 3 list([2]) 7 4 6 9 8]
#  [list([4]) 9 list([7, 8]) 3 list([6]) 1 list([4, 5]) list([4, 7]) 2]
#  [2 6 list([7, 8]) list([8]) 9 list([5, 8]) 3 list([4, 7]) 1]]
#
#
#  [[6 5 2 9 1 3 7 list([4, 8]) list([4])]
#  [8 3 1 4 2 7 list([9]) 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 list([2]) 5 list([6, 8]) list([3, 6]) list([8]) list([4, 9])
#   list([1, 4]) list([4, 9])]
#  [1 4 9 7 5 2 8 3 6]
#  [5 list([1]) 3 list([2]) 7 4 6 9 8]
#  [list([4]) 9 list([7, 8]) 3 list([6]) 1 list([4, 5]) list([4, 7]) 2]
#  [2 6 list([7, 8]) list([8]) 9 list([5, 8]) 3 list([4, 7]) 1]]
# [[6, 5, 2, 9, 1, 3, 7, [4, 8], [4]], [8, 3, 1, 4, 2, 7, [9], 6, 5], [9, 7, 4, 5, 8, 6, 1, 2, 3], [3, 8, 6, 1, 4, 9, 2, 5, 7], [7, [2], 5, [6, 8], [3, 6], [8], [4, 9], [1, 4], [4, 9]], [1, 4, 9, 7, 5, 2, 8, 3, 6], [5, [1], 3, [2], 7, 4, 6, 9, 8], [[4], 9, [7, 8], 3, [6], 1, [4, 5], [4, 7], 2], [2, 6, [7, 8], [8], 9, [5, 8], 3, [4, 7], 1]]
#
# START OVER
#
# [[6 5 2 9 1 3 7 list([4, 8]) list([4])]
#  [8 3 1 4 2 7 list([9]) 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 list([2]) 5 list([6, 8]) list([3, 6]) list([8]) list([4, 9])
#   list([1, 4]) list([4, 9])]
#  [1 4 9 7 5 2 8 3 6]
#  [5 list([1]) 3 list([2]) 7 4 6 9 8]
#  [list([4]) 9 list([7, 8]) 3 list([6]) 1 list([4, 5]) list([4, 7]) 2]
#  [2 6 list([7, 8]) list([8]) 9 list([5, 8]) 3 list([4, 7]) 1]]
#
#
#  [[6 5 2 9 1 3 7 list([4, 8]) 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 list([6, 8]) list([3, 6]) 8 list([4, 9]) list([1, 4])
#   list([4, 9])]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 list([7, 8]) 3 6 1 list([4, 5]) list([4, 7]) 2]
#  [2 6 list([7, 8]) 8 9 list([5, 8]) 3 list([4, 7]) 1]]
#
#
#  [[6 5 2 9 1 3 7 list([8]) 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 list([6]) list([3]) 8 list([4]) list([1, 4]) list([9])]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 list([7, 8]) 3 6 1 list([5]) list([7]) 2]
#  [2 6 list([7]) 8 9 list([5]) 3 list([4, 7]) 1]]
#
#
#  [[6 5 2 9 1 3 7 list([8]) 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 list([6]) list([3]) 8 list([4]) list([1, 4]) list([9])]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 list([7, 8]) 3 6 1 list([5]) list([7]) 2]
#  [2 6 list([7]) 8 9 list([5]) 3 list([4, 7]) 1]]
# [[6, 5, 2, 9, 1, 3, 7, [8], 4], [8, 3, 1, 4, 2, 7, 9, 6, 5], [9, 7, 4, 5, 8, 6, 1, 2, 3], [3, 8, 6, 1, 4, 9, 2, 5, 7], [7, 2, 5, [6], [3], 8, [4], [1, 4], [9]], [1, 4, 9, 7, 5, 2, 8, 3, 6], [5, 1, 3, 2, 7, 4, 6, 9, 8], [4, 9, [7, 8], 3, 6, 1, [5], [7], 2], [2, 6, [7], 8, 9, [5], 3, [4, 7], 1]]
#
# START OVER
#
# [[6 5 2 9 1 3 7 list([8]) 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 list([6]) list([3]) 8 list([4]) list([1, 4]) list([9])]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 list([7, 8]) 3 6 1 list([5]) list([7]) 2]
#  [2 6 list([7]) 8 9 list([5]) 3 list([4, 7]) 1]]
#
#
#  [[6 5 2 9 1 3 7 8 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 6 3 8 4 list([1, 4]) 9]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 list([7, 8]) 3 6 1 5 7 2]
#  [2 6 7 8 9 5 3 list([4, 7]) 1]]
#
#
#  [[6 5 2 9 1 3 7 8 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 6 3 8 4 list([1]) 9]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 list([8]) 3 6 1 5 7 2]
#  [2 6 7 8 9 5 3 list([4]) 1]]
#
#
#  [[6 5 2 9 1 3 7 8 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 6 3 8 4 list([1]) 9]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 list([8]) 3 6 1 5 7 2]
#  [2 6 7 8 9 5 3 list([4]) 1]]
# [[6, 5, 2, 9, 1, 3, 7, 8, 4], [8, 3, 1, 4, 2, 7, 9, 6, 5], [9, 7, 4, 5, 8, 6, 1, 2, 3], [3, 8, 6, 1, 4, 9, 2, 5, 7], [7, 2, 5, 6, 3, 8, 4, [1], 9], [1, 4, 9, 7, 5, 2, 8, 3, 6], [5, 1, 3, 2, 7, 4, 6, 9, 8], [4, 9, [8], 3, 6, 1, 5, 7, 2], [2, 6, 7, 8, 9, 5, 3, [4], 1]]
#
# START OVER
#
# [[6 5 2 9 1 3 7 8 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 6 3 8 4 list([1]) 9]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 list([8]) 3 6 1 5 7 2]
#  [2 6 7 8 9 5 3 list([4]) 1]]
#
#
#  [[6 5 2 9 1 3 7 8 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 6 3 8 4 1 9]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 8 3 6 1 5 7 2]
#  [2 6 7 8 9 5 3 4 1]]
#
#
#  [[6 5 2 9 1 3 7 8 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 6 3 8 4 1 9]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 8 3 6 1 5 7 2]
#  [2 6 7 8 9 5 3 4 1]]
#
#
#  [[6 5 2 9 1 3 7 8 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 6 3 8 4 1 9]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 8 3 6 1 5 7 2]
#  [2 6 7 8 9 5 3 4 1]]
# [[6, 5, 2, 9, 1, 3, 7, 8, 4], [8, 3, 1, 4, 2, 7, 9, 6, 5], [9, 7, 4, 5, 8, 6, 1, 2, 3], [3, 8, 6, 1, 4, 9, 2, 5, 7], [7, 2, 5, 6, 3, 8, 4, 1, 9], [1, 4, 9, 7, 5, 2, 8, 3, 6], [5, 1, 3, 2, 7, 4, 6, 9, 8], [4, 9, 8, 3, 6, 1, 5, 7, 2], [2, 6, 7, 8, 9, 5, 3, 4, 1]]
#
# FINISH!!
#  [[6 5 2 9 1 3 7 8 4]
#  [8 3 1 4 2 7 9 6 5]
#  [9 7 4 5 8 6 1 2 3]
#  [3 8 6 1 4 9 2 5 7]
#  [7 2 5 6 3 8 4 1 9]
#  [1 4 9 7 5 2 8 3 6]
#  [5 1 3 2 7 4 6 9 8]
#  [4 9 8 3 6 1 5 7 2]
#  [2 6 7 8 9 5 3 4 1]]

# %%
# board_array = [ [0,9,0, 0,0,0, 8,3,0],
#                 [0,0,3, 6,0,0, 0,4,0],
#                 [0,0,8, 0,0,0, 0,0,0],
                
#                 [2,0,0, 0,9,0, 0,0,0],
#                 [0,0,0, 4,3,8, 0,0,0],
#                 [9,0,5, 0,6,0, 0,0,0],
               
#                 [0,0,0, 7,0,0, 9,0,0],
#                 [0,0,0, 0,0,4, 0,0,6],
#                 [1,7,0, 0,0,0, 0,0,5],
#               ]

# sudoku_solver(board_array)
# Out:
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
# ...
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
# BOARD!: [[[4, 5, 6, 7], 9, [1, 2, 4, 6, 7], [1, 2, 5], [1, 2, 4, 5, 7], [1, 2, 5, 7], 8, 3, [1, 2, 7]], [[5, 7], [1, 2, 5], 3, 6, [1, 2, 5, 7, 8], [1, 2, 5, 7, 9], [1, 2, 5, 7], 4, [1, 2, 7, 9]], [[4, 5, 6, 7], [1, 2, 4, 5, 6], 8, [1, 2, 3, 5, 9], [1, 2, 4, 5, 7], [1, 2, 3, 5, 7, 9], [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [2, [1, 3, 4, 6, 8], [1, 4, 6, 7], [1, 5], 9, [1, 5, 7], [1, 3, 4, 5, 6, 7], [1, 5, 6, 7, 8], [1, 3, 4, 7, 8]], [[6, 7], [1, 6], [1, 6, 7], 4, 3, 8, [1, 2, 5, 6, 7], [1, 2, 5, 6, 7, 9], [1, 2, 7, 9]], [9, [1, 3, 4, 8], 5, [1, 2], 6, [1, 2, 7], [1, 2, 3, 4, 7], [1, 2, 7, 8], [1, 2, 3, 4, 7, 8]], [[3, 4, 5, 6, 8], [2, 3, 4, 5, 6, 8], [2, 4, 6], 7, [1, 2, 5, 8], [1, 2, 3, 5, 6], 9, [1, 2, 8], [1, 2, 3, 4, 8]], [[3, 5, 8], [2, 3, 5, 8], [2, 9], [1, 2, 3, 5, 8, 9], [1, 2, 5, 8], 4, [1, 2, 3, 7], [1, 2, 7, 8], 6], [1, 7, [2, 4, 6, 9], [2, 3, 8, 9], [2, 8], [2, 3, 6, 9], [2, 3, 4], [2, 8], 5]]
#
#
# START OVER
#
# [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
#
#
#  [[list([4, 5, 6, 7]) 9 list([1, 2, 4, 6, 7]) list([1, 2, 5])
#   list([1, 2, 4, 5, 7]) list([1, 2, 5, 7]) 8 3 list([1, 2, 7])]
#  [list([5, 7]) list([1, 2, 5]) 3 6 list([1, 2, 5, 7, 8])
#   list([1, 2, 5, 7, 9]) list([1, 2, 5, 7]) 4 list([1, 2, 7, 9])]
#  [list([4, 5, 6, 7]) list([1, 2, 4, 5, 6]) 8 list([1, 2, 3, 5, 9])
#   list([1, 2, 4, 5, 7]) list([1, 2, 3, 5, 7, 9]) list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [2 list([1, 3, 4, 6, 8]) list([1, 4, 6, 7]) list([1, 5]) 9
#   list([1, 5, 7]) list([1, 3, 4, 5, 6, 7]) list([1, 5, 6, 7, 8])
#   list([1, 3, 4, 7, 8])]
#  [list([6, 7]) list([1, 6]) list([1, 6, 7]) 4 3 8 list([1, 2, 5, 6, 7])
#   list([1, 2, 5, 6, 7, 9]) list([1, 2, 7, 9])]
#  [9 list([1, 3, 4, 8]) 5 list([1, 2]) 6 list([1, 2, 7])
#   list([1, 2, 3, 4, 7]) list([1, 2, 7, 8]) list([1, 2, 3, 4, 7, 8])]
#  [list([3, 4, 5, 6, 8]) list([2, 3, 4, 5, 6, 8]) list([2, 4, 6]) 7
#   list([1, 2, 5, 8]) list([1, 2, 3, 5, 6]) 9 list([1, 2, 8])
#   list([1, 2, 3, 4, 8])]
#  [list([3, 5, 8]) list([2, 3, 5, 8]) list([2, 9])
#   list([1, 2, 3, 5, 8, 9]) list([1, 2, 5, 8]) 4 list([1, 2, 3, 7])
#   list([1, 2, 7, 8]) 6]
#  [1 7 list([2, 4, 6, 9]) list([2, 3, 8, 9]) list([2, 8])
#   list([2, 3, 6, 9]) list([2, 3, 4]) list([2, 8]) 5]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [10], in <cell line: 14>()
#       1 board_array = [ [0,9,0, 0,0,0, 8,3,0],
#       2                 [0,0,3, 6,0,0, 0,4,0],
#       3                 [0,0,8, 0,0,0, 0,0,0],
#    (...)
#      11                 [1,7,0, 0,0,0, 0,0,5],
#      12               ]
# ---> 14 sudoku_solver(board_array)
#
# Input In [9], in sudoku_solver(board)
#      20     print("\nBOARD!:",board,"\n")
#      21     print("\nSTART OVER\n")
# ---> 22     sudoku_solver(board)
#      23 else:
#      24     print("\nFINISH!!\n",np.array(board, dtype=object))
#
# Input In [9], in sudoku_solver(board)
#      20     print("\nBOARD!:",board,"\n")
#      21     print("\nSTART OVER\n")
# ---> 22     sudoku_solver(board)
#      23 else:
#      24     print("\nFINISH!!\n",np.array(board, dtype=object))
#
#     [... skipping similar frames: sudoku_solver at line 22 (58 times)]
#
# Input In [9], in sudoku_solver(board)
#      20     print("\nBOARD!:",board,"\n")
#      21     print("\nSTART OVER\n")
# ---> 22     sudoku_solver(board)
#      23 else:
#      24     print("\nFINISH!!\n",np.array(board, dtype=object))
#
# Input In [9], in sudoku_solver(board)
#       5 fill_box(board)
#       6 print("\n"*2,np.array(board, dtype=object))
# ----> 8 remove_row_column_possibilities(board)
#       9 print("\n"*2,np.array(board, dtype=object))
#      11 remove_square_possibilities(board)
#
# Input In [2], in remove_row_column_possibilities(board)
#      59 for j in range(9):
#      60     for k in range(9):
# ---> 61         if i in board[j] or i in np.array(board, dtype=object)[:,k]:
#      62             remove_possibility(board,i,j,k)
#
# KeyboardInterrupt:

# %%
board_array = [ [1,5,0, 2,0,9, 0,0,4],
                [0,4,0, 0,0,6, 0,0,0],
                [0,0,0, 0,4,0, 0,6,3],
                
                [0,7,0, 0,0,0, 8,0,6],
                [6,0,0, 0,0,0, 0,0,5],
                [2,0,8, 0,0,0, 0,1,0],
               
                [4,6,0, 0,8,0, 0,0,0],
                [0,0,0, 6,0,0, 0,7,0],
                [8,0,0, 5,0,1, 0,4,9],
              ]

sudoku_solver(board_array)
# Out:
# [[1 5 list([3, 6, 7]) 2 list([3, 7]) 9 list([7]) list([8]) 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 3, 7, 8])
#   list([1, 3, 5, 7]) 6 list([1, 2, 5, 7, 9]) list([2, 5, 8, 9])
#   list([1, 2, 7, 8])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 7, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 3, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 3, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 7, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 7, 9]) list([3, 5, 6, 7, 9])
#   list([3, 4, 5, 7]) list([3, 4, 7, 9]) 1 list([7])]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6
#   list([2, 3, 9]) list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 3, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 list([3, 6, 7]) 2 list([3, 7]) 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 3, 7, 8])
#   list([1, 3, 5, 7]) 6 list([1, 2, 5, 7, 9]) list([2, 5, 8, 9])
#   list([1, 2, 7, 8])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 7, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 3, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 3, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 7, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 7, 9]) list([3, 5, 6, 7, 9])
#   list([3, 4, 5, 7]) list([3, 4, 7, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6
#   list([2, 3, 9]) list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 3, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 list([3, 6]) 2 list([3]) 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 3, 7, 8])
#   list([1, 3, 5, 7]) 6 list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2, 8])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 3, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 3, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([3, 5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6
#   list([2, 3, 9]) list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 3, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 list([3, 6]) 2 list([3]) 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 3, 7, 8])
#   list([1, 3, 5, 7]) 6 list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 3, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 3, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([3, 5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6
#   list([2, 3, 9]) list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 3, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, [3, 6], 2, [3], 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 3, 7, 8], [1, 3, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 3, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 3, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [3, 5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 3, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 3, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 list([3, 6]) 2 list([3]) 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 3, 7, 8])
#   list([1, 3, 5, 7]) 6 list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 3, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 3, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([3, 5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6
#   list([2, 3, 9]) list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 3, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 list([3, 6]) 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 3, 7, 8])
#   list([1, 3, 5, 7]) 6 list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 3, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 3, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([3, 5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6
#   list([2, 3, 9]) list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 3, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 list([6]) 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 3, 7, 8]) list([1, 5, 7])
#   6 list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 list([6]) 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, [6], 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 list([6]) 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
# ...
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
# BOARD!: [[1, 5, 6, 2, 3, 9, 7, 8, 4], [[3, 7, 9], 4, [2, 3, 7, 9], [1, 7, 8], [1, 5, 7], 6, [1, 2, 5, 9], [2, 5, 9], [1, 2]], [[7, 9], [2, 8, 9], [2, 7, 9], [1, 7, 8], 4, [5, 7, 8], [1, 2, 5, 9], 6, 3], [[3, 5, 9], 7, [1, 3, 4, 5, 9], [1, 3, 4, 9], [1, 2, 5, 9], [2, 3, 4, 5], 8, [2, 3, 9], 6], [6, [1, 3, 9], [1, 3, 4, 9], [1, 3, 4, 7, 8, 9], [1, 2, 7, 9], [2, 3, 4, 7, 8], [2, 3, 4, 9], [2, 3, 9], 5], [2, [3, 9], 8, [3, 4, 9], [5, 6, 9], [3, 4, 5], [3, 4, 9], 1, 7], [4, 6, [1, 2, 3, 5, 7, 9], [3, 7, 9], 8, [2, 3, 7], [1, 2, 3, 5], [2, 3, 5], [1, 2]], [[3, 5, 9], [1, 2, 3, 9], [1, 2, 3, 5, 9], 6, [2, 9], [2, 3, 4], [1, 2, 3, 5], 7, [1, 2, 8]], [8, [2, 3], [2, 3, 7], 5, [2, 7], 1, [2, 3, 6], 4, 9]]
#
#
# START OVER
#
# [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
#
#
#  [[1 5 6 2 3 9 7 8 4]
#  [list([3, 7, 9]) 4 list([2, 3, 7, 9]) list([1, 7, 8]) list([1, 5, 7]) 6
#   list([1, 2, 5, 9]) list([2, 5, 9]) list([1, 2])]
#  [list([7, 9]) list([2, 8, 9]) list([2, 7, 9]) list([1, 7, 8]) 4
#   list([5, 7, 8]) list([1, 2, 5, 9]) 6 3]
#  [list([3, 5, 9]) 7 list([1, 3, 4, 5, 9]) list([1, 3, 4, 9])
#   list([1, 2, 5, 9]) list([2, 3, 4, 5]) 8 list([2, 3, 9]) 6]
#  [6 list([1, 3, 9]) list([1, 3, 4, 9]) list([1, 3, 4, 7, 8, 9])
#   list([1, 2, 7, 9]) list([2, 3, 4, 7, 8]) list([2, 3, 4, 9])
#   list([2, 3, 9]) 5]
#  [2 list([3, 9]) 8 list([3, 4, 9]) list([5, 6, 9]) list([3, 4, 5])
#   list([3, 4, 9]) 1 7]
#  [4 6 list([1, 2, 3, 5, 7, 9]) list([3, 7, 9]) 8 list([2, 3, 7])
#   list([1, 2, 3, 5]) list([2, 3, 5]) list([1, 2])]
#  [list([3, 5, 9]) list([1, 2, 3, 9]) list([1, 2, 3, 5, 9]) 6 list([2, 9])
#   list([2, 3, 4]) list([1, 2, 3, 5]) 7 list([1, 2, 8])]
#  [8 list([2, 3]) list([2, 3, 7]) 5 list([2, 7]) 1 list([2, 3, 6]) 4 9]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 14>()
#       1 board_array = [ [1,5,0, 2,0,9, 0,0,4],
#       2                 [0,4,0, 0,0,6, 0,0,0],
#       3                 [0,0,0, 0,4,0, 0,6,3],
#    (...)
#      11                 [8,0,0, 5,0,1, 0,4,9],
#      12               ]
# ---> 14 sudoku_solver(board_array)
#
# Input In [9], in sudoku_solver(board)
#      20     print("\nBOARD!:",board,"\n")
#      21     print("\nSTART OVER\n")
# ---> 22     sudoku_solver(board)
#      23 else:
#      24     print("\nFINISH!!\n",np.array(board, dtype=object))
#
# Input In [9], in sudoku_solver(board)
#      20     print("\nBOARD!:",board,"\n")
#      21     print("\nSTART OVER\n")
# ---> 22     sudoku_solver(board)
#      23 else:
#      24     print("\nFINISH!!\n",np.array(board, dtype=object))
#
#     [... skipping similar frames: sudoku_solver at line 22 (295 times)]
#
# Input In [9], in sudoku_solver(board)
#      20     print("\nBOARD!:",board,"\n")
#      21     print("\nSTART OVER\n")
# ---> 22     sudoku_solver(board)
#      23 else:
#      24     print("\nFINISH!!\n",np.array(board, dtype=object))
#
# Input In [9], in sudoku_solver(board)
#       6 print("\n"*2,np.array(board, dtype=object))
#       8 remove_row_column_possibilities(board)
# ----> 9 print("\n"*2,np.array(board, dtype=object))
#      11 remove_square_possibilities(board)
#      12 print("\n"*2,np.array(board, dtype=object))
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~\anaconda3\lib\site-packages\ipykernel\iostream.py:216, in IOPubThread.schedule(self, f)
#     214     self._events.append(f)
#     215     # wake event thread (message content is ignored)
# --> 216     self._event_pipe.send(b'')
#     217 else:
#     218     f()
#
# File ~\anaconda3\lib\site-packages\zmq\sugar\socket.py:618, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     611         data = zmq.Frame(
#     612             data,
#     613             track=track,
#     614             copy=copy or None,
#     615             copy_threshold=self.copy_threshold,
#     616         )
#     617     data.group = group
# --> 618 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:740, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:787, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:244, in zmq.backend.cython.socket._send_copy()
#
# File ~\anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
